# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# data = pd.read_csv(".csv")
# data.head()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/iot-dataset/device_4_dataset.csv')

# %%
data.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000            60.0        0.000000e+00          1.000000
# 1          1.000000            60.0        0.000000e+00          1.000000
# 2          1.000000           342.0        0.000000e+00          1.000000
# 3          1.963325           342.0        4.370000e-11          1.977831
# 4          1.000000            60.0        0.000000e+00          1.000000
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0            60.0                 0.0          1.000000            60.0
# 1            60.0                 0.0          1.000000            60.0
# 2           342.0                 0.0          1.000000           342.0
# 3           342.0                 0.0          1.992555           342.0
# 4            60.0                 0.0          1.000000            60.0
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_covariance  \
# 0                 0.0            1.000000  ...                   0.0
# 1                 0.0            1.000000  ...                   0.0
# 2                 0.0            1.000000  ...                   0.0
# 3                 0.0            1.999253  ...                   0.0
# 4                 0.0            1.000000  ...                   0.0
#
#    HpHp_L0.1_pcc  HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# 0            0.0           1.000000        60.000000        0.000000
# 1            0.0           1.000000        60.000000        0.000000
# 2            0.0           6.249414       449.603272      122.911136
# 3            0.0           7.248947       434.759286      120.000074
# 4            0.0           1.000000        60.000000        0.000000
#
#    HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# 0             60.000000            0.00000                    0.0
# 1             60.000000            0.00000                    0.0
# 2            449.603272        15107.14730                    0.0
# 3            434.759286        14400.01777                    0.0
# 4             60.000000            0.00000                    0.0
#
#    HpHp_L0.01_pcc    type
# 0             0.0  benign
# 1             0.0  benign
# 2             0.0  benign
# 3             0.0  benign
# 4             0.0  benign
#
# [5 rows x 116 columns]

# %%
data.groupby('type')['type'].count()
# Out:
# type
# benign            175240
# gafgyt_combo       58152
# gafgyt_junk        28349
# gafgyt_scan        27859
# gafgyt_tcp         92581
# gafgyt_udp        105782
# mirai_ack          91123
# mirai_scan        103621
# mirai_syn         118128
# mirai_udp         217034
# mirai_udpplain     80808
# Name: type, dtype: int64

# %%
# data.drop(data[data["type"] == "gafgyt_tcp"].index, inplace = True)
# data.drop(data[data["type"] == "gafgyt_udp"].index, inplace = True)
# data.drop(data[data["type"] == "mirai_ack"].index, inplace = True)
data.drop(data[data["type"] == "mirai_scan"].index, inplace = True)
data.drop(data[data["type"] == "mirai_syn"].index, inplace = True)
data.drop(data[data["type"] == "mirai_udp"].index, inplace = True)
data.drop(data[data["type"] == "mirai_udpplain"].index, inplace = True)

# %%
data.groupby('type')['type'].count()
# Out:
# type
# benign          175240
# gafgyt_combo     58152
# gafgyt_junk      28349
# gafgyt_scan      27859
# gafgyt_tcp       92581
# gafgyt_udp      105782
# mirai_ack        91123
# Name: type, dtype: int64

# %%
x = data.iloc[:,:-1].values
y = data.iloc[:,-1].values

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=0)
x, y = rus.fit_resample(x, y)

# %%
from collections import Counter
print(sorted(Counter(y).items()))
# Out:
# [('benign', 27859), ('gafgyt_combo', 27859), ('gafgyt_junk', 27859), ('gafgyt_scan', 27859), ('gafgyt_tcp', 27859), ('gafgyt_udp', 27859), ('mirai_ack', 27859)]

# %%
#standardize numerical columns
# def standardize(df,col):
#     df[col]= (df[col]-df[col].mean())/df[col].std()
# data_st=data.copy()
# for i in (data_st.iloc[:,:-1].columns):
#     standardize (data_st,i)
# data_st.head()

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
y = labelencoder.fit_transform(y)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x = sc.fit_transform(x)

# %%
x = x.reshape(x.shape[0], x.shape[1], 1)
print(x.shape)
# Out:
# (195013, 115, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2,shuffle=True)

# %%
from keras import Sequential
from keras.layers import Dense, Conv1D, Flatten, MaxPooling1D

model = Sequential()
model.add(Conv1D(64, 2, activation="relu", batch_input_shape=(None, 115, 1)))
model.add(Dense(16, activation="relu"))
model.add(MaxPooling1D())
model.add(Flatten())
model.add(Dense(7, activation = 'softmax'))
model.compile(loss = 'sparse_categorical_crossentropy', 
     optimizer = "adam",               
              metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 114, 64)           192
#
#  dense (Dense)               (None, 114, 16)           1040
#
#  max_pooling1d (MaxPooling1D  (None, 57, 16)           0
#  )
#
#  flatten (Flatten)           (None, 912)               0
#
#  dense_1 (Dense)             (None, 7)                 6391
#
# =================================================================
# Total params: 7,623
# Trainable params: 7,623
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Fitting the data to the training dataset
history = model.fit(X_train,y_train, validation_data=(X_test,y_test), epochs=10)
# Out:
# Epoch 1/10
# 4876/4876 [==============================] - 37s 7ms/step - loss: 0.3629 - accuracy: 0.7825 - val_loss: 0.3439 - val_accuracy: 0.7715
# Epoch 2/10
# 4876/4876 [==============================] - 34s 7ms/step - loss: 0.2998 - accuracy: 0.8130 - val_loss: 0.2804 - val_accuracy: 0.8272
# Epoch 3/10
# 4876/4876 [==============================] - 37s 8ms/step - loss: 0.2724 - accuracy: 0.8293 - val_loss: 0.2612 - val_accuracy: 0.8348
# Epoch 4/10
# 4876/4876 [==============================] - 34s 7ms/step - loss: 0.2519 - accuracy: 0.8409 - val_loss: 0.2405 - val_accuracy: 0.8470
# Epoch 5/10
# 4876/4876 [==============================] - 34s 7ms/step - loss: 0.2394 - accuracy: 0.8469 - val_loss: 0.2304 - val_accuracy: 0.8519
# Epoch 6/10
# 4876/4876 [==============================] - 36s 7ms/step - loss: 0.2310 - accuracy: 0.8502 - val_loss: 0.2394 - val_accuracy: 0.8451
# Epoch 7/10
# 4876/4876 [==============================] - 36s 7ms/step - loss: 0.2257 - accuracy: 0.8508 - val_loss: 0.2184 - val_accuracy: 0.8543
# Epoch 8/10
# 4876/4876 [==============================] - 36s 7ms/step - loss: 0.2207 - accuracy: 0.8518 - val_loss: 0.2148 - val_accuracy: 0.8562
# Epoch 9/10
# 4876/4876 [==============================] - 38s 8ms/step - loss: 0.2194 - accuracy: 0.8522 - val_loss: 0.2155 - val_accuracy: 0.8558
# Epoch 10/10
# 4876/4876 [==============================] - 38s 8ms/step - loss: 0.2162 - accuracy: 0.8539 - val_loss: 0.2134 - val_accuracy: 0.8568

# %%
y_pred=model.predict(X_test)
y_pred = y_pred.argmax(axis=-1)

# %% [markdown]
# # **ploting and results**

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, matthews_corrcoef, f1_score, precision_score, recall_score

print(f"Accuracy   : {accuracy_score(y_test, y_pred)}")
# print(f"Precision  : {precision_score(y_test, y_pred)}")
# print(f"F1-Measure : {f1_score(y_test, y_pred)}")
print(f"MCC        : {matthews_corrcoef(y_test, y_pred)}")
# print(f"Recall     : {recall_score(y_test, y_pred)}")
# Out:
# Accuracy   : 0.8567802476732559
# MCC        : 0.8532063857428237

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5582
#            1       0.99      1.00      1.00      5633
#            2       1.00      0.99      1.00      5548
#            3       1.00      1.00      1.00      5451
#            4       0.50      1.00      0.67      5572
#            5       1.00      0.00      0.00      5545
#            6       1.00      1.00      1.00      5672
#
#     accuracy                           0.86     39003
#    macro avg       0.93      0.86      0.81     39003
# weighted avg       0.93      0.86      0.81     39003

# %%
#Accuracy

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(1,len(acc) + 1)
plt.plot(epochs, acc, label='Training accuracy')
plt.plot(epochs, val_acc , label='Validation accuracy')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.ylim([0.5, 1])
plt.legend(['train', 'test'], loc='upper left')
plt.show()

plt.plot(epochs, acc, label='Training accuracy')
plt.plot(epochs, val_acc , label='Validation accuracy')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.ylim([0, 1])
plt.legend(['train', 'test'], loc='upper left')
plt.show()




#Loss

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1,len(loss) + 1)
plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss , label='Validation loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.ylim([0, 0.5])
plt.legend(['train', 'test'], loc='upper left')
plt.show()


plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss , label='Validation loss')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.ylim([0, 1])
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Accuracy
acc = history.history['accuracy']
acc_val = history.history['val_accuracy']
epochs = range(1,len(acc) + 1)
plt.plot(epochs, acc, 'g', label='Training accuracy')
plt.plot(epochs, acc_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')
plt.show()


plt.plot(epochs, acc, 'g', label='Training accuracy')
plt.plot(epochs, acc_val, 'b', label='validation accuracy')
plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()


#loss
loss = history.history['loss']
loss_val = history.history['val_loss']
epochs = range(1,len(acc) + 1)
plt.plot(epochs, loss, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim([0, 0.5])
plt.legend(loc='upper right')
plt.show()



plt.plot(epochs, loss, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend(loc='upper right')
plt.show()

# %%
#Confusion matrix 
import seaborn as sns
cm = confusion_matrix(y_test, y_pred)
print(cm)
sns.heatmap(cm, annot=True)
# Out:
# [[5580    0    0    2    0    0    0]
#  [   0 5622   11    0    0    0    0]
#  [   0   30 5517    1    0    0    0]
#  [   0    1    0 5450    0    0    0]
#  [   0    0    0    1 5571    0    0]
#  [   1    0    1    0 5538    5    0]
#  [   0    0    0    0    0    0 5672]]

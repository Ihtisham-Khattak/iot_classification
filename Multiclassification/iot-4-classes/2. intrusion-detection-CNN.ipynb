# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# data = pd.read_csv(".csv")
# data.head()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
benign=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/iot-dataset/2/2.benign.csv')
g_c=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/iot-dataset/2/2.gafgyt.combo.csv')
g_j=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/iot-dataset/2/2.gafgyt.junk.csv')
g_s=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/iot-dataset/2/2.gafgyt.scan.csv')
# g_t=pd.read_csv('/content/drive/MyDrive/iot-dataset/2/2.gafgyt.tcp.csv')
# g_u=pd.read_csv('/content/drive/MyDrive/iot-dataset/2/2.gafgyt.udp.csv')
# m_a=pd.read_csv('/content/drive/MyDrive/iot-dataset/2/2.mirai.ack.csv')
# m_sc=pd.read_csv('/content/drive/MyDrive/iot-dataset/2/2.mirai.scan.csv')
# m_sy=pd.read_csv('/content/drive/MyDrive/iot-dataset/2/2.mirai.syn.csv')
# m_u=pd.read_csv('/content/drive/MyDrive/iot-dataset/2/2.mirai.udp.csv')
# m_u_p=pd.read_csv('/content/drive/MyDrive/iot-dataset/2/2.mirai.udpplain.csv')

# %%
benign['type']='benign'
# m_u['type']='attack'
g_c['type']='combo'
g_j['type']='junk'
g_s['type']='scan'
# g_t['type']='attack'
# g_u['type']='attack'
# m_a['type']='attack'
# m_sc['type']='attack'
# m_sy['type']='attack'
# m_u_p['type']='attack'

# %%
data=pd.concat([benign,g_c,g_j,g_s],
               axis=0, sort=False, ignore_index=True)

# %%
data.head()
# Out:
#    MI_dir_L5_weight  MI_dir_L5_mean  MI_dir_L5_variance  MI_dir_L3_weight  \
# 0          1.000000       60.000000            0.000000          1.000000
# 1          1.000000      110.000000            0.000000          1.000000
# 2          1.724055       91.439104          249.441812          1.823878
# 3          1.000000      342.000000            0.000000          1.000000
# 4          2.516815       90.867308          150.827639          2.688981
#
#    MI_dir_L3_mean  MI_dir_L3_variance  MI_dir_L1_weight  MI_dir_L1_mean  \
# 0       60.000000            0.000000          1.000000       60.000000
# 1      110.000000            0.000000          1.000000      110.000000
# 2       92.454965          253.612868          1.937463       93.483558
# 3      342.000000            0.000000          1.000000      342.000000
# 4       91.541993          160.705060          2.888469       92.277536
#
#    MI_dir_L1_variance  MI_dir_L0.1_weight  ...  HpHp_L0.1_covariance  \
# 0            0.000000            1.000000  ...                   0.0
# 1            0.000000            1.000000  ...                   0.0
# 2          255.733288            1.993563  ...                   0.0
# 3            0.000000            1.000000  ...                   0.0
# 4          169.944112            2.988463  ...                   0.0
#
#    HpHp_L0.1_pcc  HpHp_L0.01_weight  HpHp_L0.01_mean  HpHp_L0.01_std  \
# 0            0.0           1.000000        60.000000        0.000000
# 1            0.0           1.238636       106.146795        7.887770
# 2            0.0           1.000000        78.000000        0.000000
# 3            0.0           2.487473       341.959189        7.347919
# 4            0.0           2.237519        98.930412        9.942635
#
#    HpHp_L0.01_magnitude  HpHp_L0.01_radius  HpHp_L0.01_covariance  \
# 0             60.000000           0.000000                    0.0
# 1            106.146795          62.216910                    0.0
# 2             78.000000           0.000000                    0.0
# 3            341.959189          53.991908                    0.0
# 4             98.930412          98.855983                    0.0
#
#    HpHp_L0.01_pcc    type
# 0             0.0  benign
# 1             0.0  benign
# 2             0.0  benign
# 3             0.0  benign
# 4             0.0  benign
#
# [5 rows x 116 columns]

# %%
x = data.iloc[:,:-1].values
y = data.iloc[:,-1].values

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=0)
x, y = rus.fit_resample(x, y)

# %%
from collections import Counter
print(sorted(Counter(y).items()))
# Out:
# [('benign', 13113), ('combo', 13113), ('junk', 13113), ('scan', 13113)]

# %%
#standardize numerical columns
# def standardize(df,col):
#     df[col]= (df[col]-df[col].mean())/df[col].std()
# data_st=data.copy()
# for i in (data_st.iloc[:,:-1].columns):
#     standardize (data_st,i)
# data_st.head()

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
y = labelencoder.fit_transform(y)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x = sc.fit_transform(x)

# %%
x = x.reshape(x.shape[0], x.shape[1], 1)
print(x.shape)
# Out:
# (52452, 115, 1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2,shuffle=True)

# %%
from keras import Sequential
from keras.layers import Dense, Conv1D, Flatten, MaxPooling1D

model = Sequential()
model.add(Conv1D(64, 2, activation="relu", batch_input_shape=(None, 115, 1)))
model.add(Dense(16, activation="relu"))
model.add(MaxPooling1D())
model.add(Flatten())
model.add(Dense(4, activation = 'softmax'))
model.compile(loss = 'sparse_categorical_crossentropy', 
     optimizer = "adam",               
              metrics = ['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_1 (Conv1D)           (None, 114, 64)           192
#
#  dense_2 (Dense)             (None, 114, 16)           1040
#
#  max_pooling1d_1 (MaxPooling  (None, 57, 16)           0
#  1D)
#
#  flatten_1 (Flatten)         (None, 912)               0
#
#  dense_3 (Dense)             (None, 4)                 3652
#
# =================================================================
# Total params: 4,884
# Trainable params: 4,884
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Fitting the data to the training dataset
history = model.fit(X_train,y_train, validation_data=(X_test,y_test), epochs=10)
# Out:
# Epoch 1/10
# 1312/1312 [==============================] - 12s 8ms/step - loss: 0.2860 - accuracy: 0.8537 - val_loss: 0.2440 - val_accuracy: 0.8574
# Epoch 2/10
# 1312/1312 [==============================] - 9s 7ms/step - loss: 0.2101 - accuracy: 0.8930 - val_loss: 0.1758 - val_accuracy: 0.9135
# Epoch 3/10
# 1312/1312 [==============================] - 11s 9ms/step - loss: 0.1608 - accuracy: 0.9281 - val_loss: 0.1403 - val_accuracy: 0.9495
# Epoch 4/10
# 1312/1312 [==============================] - 9s 7ms/step - loss: 0.1304 - accuracy: 0.9459 - val_loss: 0.1106 - val_accuracy: 0.9599
# Epoch 5/10
# 1312/1312 [==============================] - 9s 7ms/step - loss: 0.1103 - accuracy: 0.9577 - val_loss: 0.0917 - val_accuracy: 0.9808
# Epoch 6/10
# 1312/1312 [==============================] - 9s 7ms/step - loss: 0.0898 - accuracy: 0.9712 - val_loss: 0.0738 - val_accuracy: 0.9850
# Epoch 7/10
# 1312/1312 [==============================] - 9s 7ms/step - loss: 0.0777 - accuracy: 0.9772 - val_loss: 0.0617 - val_accuracy: 0.9874
# Epoch 8/10
# 1312/1312 [==============================] - 11s 8ms/step - loss: 0.0668 - accuracy: 0.9818 - val_loss: 0.0588 - val_accuracy: 0.9844
# Epoch 9/10
# 1312/1312 [==============================] - 15s 12ms/step - loss: 0.0602 - accuracy: 0.9831 - val_loss: 0.0450 - val_accuracy: 0.9944
# Epoch 10/10
# 1312/1312 [==============================] - 13s 10ms/step - loss: 0.0492 - accuracy: 0.9879 - val_loss: 0.0410 - val_accuracy: 0.9921

# %%
y_pred=model.predict(X_test)
y_pred = y_pred.argmax(axis=-1)

# %% [markdown]
# # **ploting and results**

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, matthews_corrcoef, f1_score, precision_score, recall_score

print(f"Accuracy   : {accuracy_score(y_test, y_pred)}")
# print(f"Precision  : {precision_score(y_test, y_pred)}")
# print(f"F1-Measure : {f1_score(y_test, y_pred)}")
print(f"MCC        : {matthews_corrcoef(y_test, y_pred)}")
# print(f"Recall     : {recall_score(y_test, y_pred)}")
# Out:
# Accuracy   : 0.9920884567724716
# MCC        : 0.9895128796519232

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      2638
#            1       1.00      0.97      0.98      2633
#            2       0.97      1.00      0.99      2651
#            3       1.00      1.00      1.00      2569
#
#     accuracy                           0.99     10491
#    macro avg       0.99      0.99      0.99     10491
# weighted avg       0.99      0.99      0.99     10491

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1,len(loss) + 1)
plt.plot(epochs,loss,'y',label='Tranning loss')
plt.plot(epochs,val_loss,'r',label='Validation loss')
plt.title('Traning and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Traning and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim([0.8, 1])
plt.show()

# %%
#Confusion matrix 
import seaborn as sns
cm = confusion_matrix(y_test, y_pred)
print(cm)
sns.heatmap(cm, annot=True)
# Out:
# [[2635    0    0    3]
#  [   0 2557   76    0]
#  [   0    4 2647    0]
#  [   0    0    0 2569]]
